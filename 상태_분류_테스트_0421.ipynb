# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 라이브러리 불러오기

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pathlib

import tensorflow as tf
import tensorflow_datasets as tfds

from keras.models import load_model

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 사물의 클래스 분류

# %%
basePath = '/content/drive/MyDrive/Colab Notebooks/dacon/'

# %%
test_dir = basePath + "test"
test_dir = pathlib.Path(test_dir)

# %%
batch_size = 32
img_height = 224
img_width = 224

# %%
image_count = len(list(test_dir.glob('*/*.png')))
print(image_count)
# Out:
# 2154

# %%
class_names = ['bottle', 'cable', 'capsule', 'carpet', 'grid', 
               'hazelnut', 'leather', 'metal_nut', 'pill', 'screw', 
               'tile', 'toothbrush', 'transistor', 'wood', 'zipper']

# %%
imageList = list(test_dir.glob('*/*.png'))
# print(imageList)

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    labels = None,
    seed = 12,
    shuffle = False,
    image_size = (img_height, img_width),
    batch_size = batch_size
)
# Out:
# Found 2154 files belonging to 1 classes.

# %%
test_df = pd.read_csv(basePath + 'test_df.csv')
test_df.head()
# Out:
#    index  file_name
# 0      0  20000.png
# 1      1  20001.png
# 2      2  20002.png
# 3      3  20003.png
# 4      4  20004.png

# %%
model = load_model(basePath + 'train/model/model_class15.h5')

# %%
test_list = model.predict(test_ds)

# %%
accuracy_list = []

for i in range(len(test_list)):
    id = np.argmax(test_list[i])
    accuracy_list.append(id)

# %%
accuracy_list2 = accuracy_list.copy()

accuracy_list3 = []
for i in range(len(accuracy_list2)):
  accuracy_list3.append(class_names[accuracy_list[i]])

# %%
accuracy_df = pd.DataFrame(accuracy_list3, columns = ['class']) # 데이터프레임으로 변환
class_df = pd.concat([test_df, accuracy_df], axis = 1)

# %%
class_df.head()
# Out:
#    index  file_name       class
# 0      0  20000.png        tile
# 1      1  20001.png        grid
# 2      2  20002.png  transistor
# 3      3  20003.png        tile
# 4      4  20004.png        tile

# %% [markdown]
# # 테스트 데이터셋 구축

# %%
from PIL import Image

# %%
filepath = basePath + "test/test"  

classes = os.listdir(filepath)

# 이미지 저장할 상위 폴더
dir_path = basePath + 'class'

# dir_path 폴더 없으면 생성
if os.path.isdir(dir_path) == False:
    os.mkdir(dir_path)

for i, cls in enumerate(classes):
    image = Image.open(filepath + '/' + cls)
    
    filter1 = (class_df['file_name'] == cls)
    df = class_df[filter1]
    class1 = df['class'].values[0]

    # 클래스별 폴더 경로
    folder_path = dir_path + '/' + class1

    # 폴더 없으면 생성
    if os.path.isdir(folder_path) == False:
        os.mkdir(folder_path)

    # 이미지 폴더에 저장
    image.save(folder_path + '/' + cls, format = None)

# %% [markdown]
# # 클래스별 상태 분류

# %%
# 사물의 종류 상태 가져오기
def get_state(class1):
    state_path = basePath + '/train/data_train_state/' + class1
    classes = os.listdir(state_path)
    classes = natsort.natsorted(classes)

    state = []
    for i, cls in enumerate(classes):
        state.append(cls)
        
    print(class1, " : ", state)
    return classes

# %%
import natsort
from PIL import Image

dataPath = basePath + "class" # 클래스별 이미지 경로
classes1 = os.listdir(dataPath)
classes1 = natsort.natsorted(classes1) # 정렬

class_pred_df = pd.DataFrame()
for i, cls in enumerate(classes1):
  print(cls)
  state_dir = basePath + 'class/' + cls
  state_dir = pathlib.Path(state_dir)

  test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    state_dir,
    labels = None,
    seed = 12,
    shuffle = False,
    image_size = (img_height, img_width),
    batch_size = batch_size
  )

  # 클래스별 모델 불러오기
  model_state = load_model(basePath + 'train/model/' + cls + '.h5')
  predictions = model_state.predict(test_ds)

  # 상태 불러오기
  state = get_state(cls)

  state_list = []
  for j in range(len(predictions)):
    id = np.argmax(predictions[j])
    state1 = state[id]
    label1 = cls + '-' + state1
    state_list.append(label1)

  # 이미지 파일명 가져오기
  fileNameList = os.listdir(state_dir)
  fileNameList.sort()

  fileName_df = pd.DataFrame(fileNameList)
  state_df = pd.DataFrame(state_list)

  data = pd.DataFrame({'file_name' : fileNameList,
                       'label' : state_list})
  
  class_pred_df = pd.concat([class_pred_df, data], ignore_index = True)
  print(class_pred_df)
# Out:
# bottle
# Found 102 files belonging to 1 classes.
# bottle  :  ['broken_large', 'broken_small', 'contamination', 'good']
#      file_name                 label
# 0    20010.png   bottle-broken_large
# 1    20015.png  bottle-contamination
# 2    20022.png   bottle-broken_large
# 3    20085.png   bottle-broken_large
# 4    20105.png  bottle-contamination
# ..         ...                   ...
# 97   22003.png           bottle-good
# 98   22010.png   bottle-broken_small
# 99   22072.png   bottle-broken_large
# 100  22082.png           bottle-good
# 101  22126.png   bottle-broken_large
#
# [102 rows x 2 columns]
# cable
# Found 206 files belonging to 1 classes.
# cable  :  ['bent_wire', 'cable_swap', 'combined', 'cut_inner_insulation', 'cut_outer_insulation', 'good', 'missing_cable', 'missing_wire', 'poke_insulation']
#      file_name                 label
# 0    20010.png   bottle-broken_large
# 1    20015.png  bottle-contamination
# 2    20022.png   bottle-broken_large
# 3    20085.png   bottle-broken_large
# 4    20105.png  bottle-contamination
# ..         ...                   ...
# 303  22111.png       cable-bent_wire
# 304  22118.png            cable-good
# 305  22146.png            cable-good
# 306  22148.png            cable-good
# 307  22152.png            cable-good
#
# [308 rows x 2 columns]
# capsule
# Found 152 files belonging to 1 classes.
# capsule  :  ['crack', 'faulty_imprint', 'good', 'poke', 'scratch', 'squeeze']
#      file_name                   label
# 0    20010.png     bottle-broken_large
# 1    20015.png    bottle-contamination
# 2    20022.png     bottle-broken_large
# 3    20085.png     bottle-broken_large
# 4    20105.png    bottle-contamination
# ..         ...                     ...
# 455  22089.png            capsule-good
# 456  22090.png            capsule-good
# 457  22105.png            capsule-poke
# 458  22116.png  capsule-faulty_imprint
# 459  22125.png            capsule-good
#
# [460 rows x 2 columns]
# carpet
# Found 136 files belonging to 1 classes.
# carpet  :  ['color', 'cut', 'good', 'hole', 'metal_contamination', 'thread']
#      file_name                 label
# 0    20010.png   bottle-broken_large
# 1    20015.png  bottle-contamination
# 2    20022.png   bottle-broken_large
# 3    20085.png   bottle-broken_large
# 4    20105.png  bottle-contamination
# ..         ...                   ...
# 591  22073.png           carpet-hole
# 592  22075.png           carpet-good
# 593  22091.png           carpet-good
# 594  22110.png          carpet-color
# 595  22136.png           carpet-good
#
# [596 rows x 2 columns]
# grid
# Found 108 files belonging to 1 classes.
# grid  :  ['bent', 'broken', 'glue', 'good', 'metal_contamination', 'thread']
#      file_name                 label
# 0    20010.png   bottle-broken_large
# 1    20015.png  bottle-contamination
# 2    20022.png   bottle-broken_large
# 3    20085.png   bottle-broken_large
# 4    20105.png  bottle-contamination
# ..         ...                   ...
# 699  22132.png             grid-good
# 700  22133.png           grid-broken
# 701  22135.png             grid-good
# 702  22147.png           grid-broken
# 703  22151.png             grid-good
#
# [704 rows x 2 columns]
# hazelnut
# Found 148 files belonging to 1 classes.
# hazelnut  :  ['crack', 'cut', 'good', 'hole', 'print']
#      file_name                 label
# 0    20010.png   bottle-broken_large
# 1    20015.png  bottle-contamination
# 2    20022.png   bottle-broken_large
# 3    20085.png   bottle-broken_large
# 4    20105.png  bottle-contamination
# ..         ...                   ...
# 847  22067.png         hazelnut-good
# 848  22084.png         hazelnut-good
# 849  22087.png         hazelnut-good
# 850  22109.png         hazelnut-good
# 851  22122.png        hazelnut-print
#
# [852 rows x 2 columns]
# leather
# Found 139 files belonging to 1 classes.
# leather  :  ['color', 'cut', 'fold', 'glue', 'good', 'poke']
#      file_name                 label
# 0    20010.png   bottle-broken_large
# 1    20015.png  bottle-contamination
# 2    20022.png   bottle-broken_large
# 3    20085.png   bottle-broken_large
# 4    20105.png  bottle-contamination
# ..         ...                   ...
# 986  22051.png           leather-cut
# 987  22059.png         leather-color
# 988  22063.png         leather-color
# 989  22107.png          leather-good
# 990  22114.png         leather-color
#
# [991 rows x 2 columns]
# metal_nut
# Found 134 files belonging to 1 classes.
# metal_nut  :  ['bent', 'color', 'flip', 'good', 'scratch']
#       file_name                 label
# 0     20010.png   bottle-broken_large
# 1     20015.png  bottle-contamination
# 2     20022.png   bottle-broken_large
# 3     20085.png   bottle-broken_large
# 4     20105.png  bottle-contamination
# ...         ...                   ...
# 1120  22098.png        metal_nut-good
# 1121  22106.png        metal_nut-good
# 1122  22108.png        metal_nut-good
# 1123  22134.png        metal_nut-bent
# 1124  22145.png     metal_nut-scratch
#
# [1125 rows x 2 columns]
# pill
# Found 191 files belonging to 1 classes.
# pill  :  ['color', 'combined', 'contamination', 'crack', 'faulty_imprint', 'good', 'pill_type', 'scratch']
#       file_name                 label
# 0     20010.png   bottle-broken_large
# 1     20015.png  bottle-contamination
# 2     20022.png   bottle-broken_large
# 3     20085.png   bottle-broken_large
# 4     20105.png  bottle-contamination
# ...         ...                   ...
# 1311  22112.png             pill-good
# 1312  22119.png             pill-good
# 1313  22131.png             pill-good
# 1314  22138.png    pill-contamination
# 1315  22141.png   pill-faulty_imprint
#
# [1316 rows x 2 columns]
# screw
# Found 198 files belonging to 1 classes.
# screw  :  ['good', 'manipulated_front', 'scratch_head', 'scratch_neck', 'thread_side', 'thread_top']
#       file_name                 label
# 0     20010.png   bottle-broken_large
# 1     20015.png  bottle-contamination
# 2     20022.png   bottle-broken_large
# 3     20085.png   bottle-broken_large
# 4     20105.png  bottle-contamination
# ...         ...                   ...
# 1509  22115.png            screw-good
# 1510  22117.png            screw-good
# 1511  22120.png            screw-good
# 1512  22127.png            screw-good
# 1513  22150.png            screw-good
#
# [1514 rows x 2 columns]
# tile
# Found 153 files belonging to 1 classes.
# tile  :  ['crack', 'glue_strip', 'good', 'gray_stroke', 'oil', 'rough']
#       file_name                 label
# 0     20010.png   bottle-broken_large
# 1     20015.png  bottle-contamination
# 2     20022.png   bottle-broken_large
# 3     20085.png   bottle-broken_large
# 4     20105.png  bottle-contamination
# ...         ...                   ...
# 1662  22100.png             tile-good
# 1663  22123.png             tile-good
# 1664  22129.png             tile-good
# 1665  22144.png             tile-good
# 1666  22149.png      tile-gray_stroke
#
# [1667 rows x 2 columns]
# toothbrush
# Found 54 files belonging to 1 classes.
# toothbrush  :  ['defective', 'good']
#       file_name                 label
# 0     20010.png   bottle-broken_large
# 1     20015.png  bottle-contamination
# 2     20022.png   bottle-broken_large
# 3     20085.png   bottle-broken_large
# 4     20105.png  bottle-contamination
# ...         ...                   ...
# 1716  21952.png       toothbrush-good
# 1717  21954.png  toothbrush-defective
# 1718  22137.png  toothbrush-defective
# 1719  22142.png  toothbrush-defective
# 1720  22143.png       toothbrush-good
#
# [1721 rows x 2 columns]
# transistor
# Found 156 files belonging to 1 classes.
# transistor  :  ['bent_lead', 'cut_lead', 'damaged_case', 'good', 'misplaced']
#       file_name                 label
# 0     20010.png   bottle-broken_large
# 1     20015.png  bottle-contamination
# 2     20022.png   bottle-broken_large
# 3     20085.png   bottle-broken_large
# 4     20105.png  bottle-contamination
# ...         ...                   ...
# 1872  22061.png       transistor-good
# 1873  22086.png       transistor-good
# 1874  22096.png  transistor-misplaced
# 1875  22103.png       transistor-good
# 1876  22121.png       transistor-good
#
# [1877 rows x 2 columns]
# wood
# Found 96 files belonging to 1 classes.
# wood  :  ['color', 'combined', 'good', 'hole', 'liquid', 'scratch']
#       file_name                 label
# 0     20010.png   bottle-broken_large
# 1     20015.png  bottle-contamination
# 2     20022.png   bottle-broken_large
# 3     20085.png   bottle-broken_large
# 4     20105.png  bottle-contamination
# ...         ...                   ...
# 1968  22018.png         wood-combined
# 1969  22028.png          wood-scratch
# 1970  22124.png             wood-good
# 1971  22128.png             wood-good
# 1972  22139.png             wood-hole
#
# [1973 rows x 2 columns]
# zipper
# Found 181 files belonging to 1 classes.
# zipper  :  ['broken_teeth', 'combined', 'fabric_border', 'fabric_interior', 'good', 'rough', 'split_teeth', 'squeezed_teeth']
#       file_name                 label
# 0     20010.png   bottle-broken_large
# 1     20015.png  bottle-contamination
# 2     20022.png   bottle-broken_large
# 3     20085.png   bottle-broken_large
# 4     20105.png  bottle-contamination
# ...         ...                   ...
# 2149  22071.png           zipper-good
# 2150  22085.png          zipper-rough
# 2151  22113.png    zipper-split_teeth
# 2152  22140.png    zipper-split_teeth
# 2153  22153.png           zipper-good
#
# [2154 rows x 2 columns]

# %%
class_pred_df = class_pred_df.sort_values('file_name')
class_pred_df.reset_index(drop = True)
# Out:
#       file_name             label
# 0     20000.png   tile-glue_strip
# 1     20001.png       grid-thread
# 2     20002.png   transistor-good
# 3     20003.png   tile-glue_strip
# 4     20004.png         tile-good
# ...         ...               ...
# 2149  22149.png  tile-gray_stroke
# 2150  22150.png        screw-good
# 2151  22151.png         grid-good
# 2152  22152.png        cable-good
# 2153  22153.png       zipper-good
#
# [2154 rows x 2 columns]

# %%
# class_pred_df = pd.DataFrame(class_pred_list, columns = ['file_name', 'label'])
df_test = pd.merge(class_df, class_pred_df, on = 'file_name')
df_test
# Out:
#       index  file_name       class             label
# 0         0  20000.png        tile   tile-glue_strip
# 1         1  20001.png        grid       grid-thread
# 2         2  20002.png  transistor   transistor-good
# 3         3  20003.png        tile   tile-glue_strip
# 4         4  20004.png        tile         tile-good
# ...     ...        ...         ...               ...
# 2149   2149  22149.png        tile  tile-gray_stroke
# 2150   2150  22150.png       screw        screw-good
# 2151   2151  22151.png        grid         grid-good
# 2152   2152  22152.png       cable        cable-good
# 2153   2153  22153.png      zipper       zipper-good
#
# [2154 rows x 4 columns]

# %%
df_test = df_test[['index', 'label']]
df_test
# Out:
#       index             label
# 0         0   tile-glue_strip
# 1         1       grid-thread
# 2         2   transistor-good
# 3         3   tile-glue_strip
# 4         4         tile-good
# ...     ...               ...
# 2149   2149  tile-gray_stroke
# 2150   2150        screw-good
# 2151   2151         grid-good
# 2152   2152        cable-good
# 2153   2153       zipper-good
#
# [2154 rows x 2 columns]

# %% [markdown]
# # 엑셀파일로 저장

# %%
df_test.to_csv(basePath + "test_220421.csv", index = False, mode = 'w')
